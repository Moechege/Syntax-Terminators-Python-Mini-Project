# %%
#import libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#load datasets 
#load Telcom dataset 1 and assign it variable df1

df1=pd.read_csv('C:\\Users\\mac\Downloads\Telcom_dataset.csv')
df1.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
#load Telcom dataset day 2 and assign it variable df2 

df2=pd.read_csv('C:\\Users\\mac\Downloads\Telcom_dataset2.csv')
df2.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
#load Telcom Dataset 3 and assign it variable df3 

df3=pd.read_csv('C:\\Users\\mac\Downloads\Telcom_dataset3.csv')
df3.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
#rename columns according to description given in geodata sets

#df1
dict={'PRODUTC':'PRODUCT','DATETIME':'DATE_TIME','DW_A_NUMBER':'DW_A_NUMBER_INT',
     'DW_B_NUMBER':'DW_B_NUMBER_INT' ,'CELLID':'CELL_ID','SIET_ID':'SITE_ID'}
df1.rename(columns=dict,inplace=True)
display(df1)

#df2
df2.rename(columns=dict,inplace=True)
display(df2)

#df3
df3.rename(columns=dict,inplace=True)
display(df3)
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0     1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3     6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4     02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv
# ...               ...       ...       ...         ...         ...
# 4996  38811081cf82c90     19e2e     OTHER  0c2371d9bc  1e751d08a4
# 4997  6ec63d4aa5de5dd     19e2e     19e2e  5fb791cf56  65efe2bc62
# 4998  1a49f8b0ded9de6     19e2e     19e2e  7773627c12  9ef9616350
# 4999  bd663f07b6c8bcd     19e2e     19e2e  3f4af49d6c  969b8d0e39
# 5000  3600efd094f2225     19e2e     19e2e  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 10 columns]
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0     1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1     87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2     93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3     7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4     56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO
# ...               ...       ...       ...         ...         ...
# 4996  8db839a0c08bd54     19e2e     19e2e  896459aace  b7d00e59e4
# 4997  5a2848d6f983c31     19e2e     19e2e  7e90b35166  211015b14d
# 4998  7185a95077eae9e     19e2e     19e2e  fe70e431df  c7ea989264
# 4999  5a4dc9e82deb309     19e2e     OTHER  ffa6759bb2         NaN
# 5000  de590e98879fa37     19e2e     19e2e  8630058aca  b47a998a3e
#
# [5001 rows x 10 columns]
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1        sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2      Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3        sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4      Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0     ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2     52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4     2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA
# ...               ...       ...       ...         ...         ...
# 4996  0ab2acd804d01fe     19e2e     19e2e  2aa04dcab7  f7d63a29e5
# 4997  4c8098eb6ea1a41     19e2e     19e2e  7f1f2f889f  b4ddb9e93c
# 4998  9d064f013e2cab2     19e2e     19e2e  a4731e780e  d68260ef50
# 4999  f9ff5af59cf0d68     19e2e     19e2e  98ed726da2  b4130b54ab
# 5000  7e60838216482a7     19e2e     19e2e  1c11a2fcbb  6d70dae094
#
# [5001 rows x 10 columns]

# %%
#conducting exploratory analysis 
#getting information and descriptive statistics from the three datasets 

df1.info()
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          5001 non-null   object
#  1   VALUE            5001 non-null   int64
#  2   DATE_TIME        5001 non-null   object
#  3   CELL_ON_SITE     5001 non-null   object
#  4   DW_A_NUMBER_INT  5001 non-null   object
#  5   DW_B_NUMBER_INT  5001 non-null   object
#  6   COUNTRY_A        5001 non-null   object
#  7   COUNTRY_B        5001 non-null   object
#  8   CELL_ID          5001 non-null   object
#  9   SITE_ID          4285 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB
#              VALUE
# count  5001.000000
# mean     25.869626
# std     101.934502
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%      25.000000
# max    4440.000000

# %%
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          5001 non-null   object
#  1   VALUE            5001 non-null   int64
#  2   DATE_TIME        5001 non-null   object
#  3   CELL_ON_SITE     5001 non-null   object
#  4   DW_A_NUMBER_INT  5001 non-null   object
#  5   DW_B_NUMBER_INT  5001 non-null   object
#  6   COUNTRY_A        5001 non-null   object
#  7   COUNTRY_B        5001 non-null   object
#  8   CELL_ID          5001 non-null   object
#  9   SITE_ID          4325 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB
#              VALUE
# count  5001.000000
# mean     24.334933
# std      97.471586
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%      25.000000
# max    3380.000000

# %%
df3.info()
df3.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          5001 non-null   object
#  1   VALUE            5001 non-null   int64
#  2   DATE_TIME        5001 non-null   object
#  3   CELL_ON_SITE     5001 non-null   object
#  4   DW_A_NUMBER_INT  5001 non-null   object
#  5   DW_B_NUMBER_INT  5001 non-null   object
#  6   COUNTRY_A        5001 non-null   object
#  7   COUNTRY_B        5001 non-null   object
#  8   CELL_ID          5001 non-null   object
#  9   SITE_ID          4396 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB
#               VALUE
# count   5001.000000
# mean      26.441512
# std      224.200217
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       25.000000
# max    12900.000000

# %%
# observations from the telcom datasets
#what was the most used product on day one, day two and day three 
#day one
df1['PRODUCT'].value_counts().idxmax()

# what was the highest amount of money spent on voice and sms in the three days
# Out:
# 'Voice'

# %%
#day two
df2['PRODUCT'].value_counts().idxmax()
# Out:
# 'sms'

# %%
#day three
df3['PRODUCT'].value_counts().idxmax()
# Out:
# 'sms'

# %%
# what was the highest amount of money spent on voice and sms in the three days
#day one 
df1.groupby('PRODUCT').VALUE.max()
# Out:
# PRODUCT
# Voice    1860
# data     4440
# sms       100
# Name: VALUE, dtype: int64

# %%
#day two
df2.groupby('PRODUCT').VALUE.max()
# Out:
# PRODUCT
# Voice    3380
# data     1000
# sms       100
# Name: VALUE, dtype: int64

# %%
#day three
df3.groupby('PRODUCT').VALUE.max()
# Out:
# PRODUCT
# Voice    12900
# data       832
# sms        100
# Name: VALUE, dtype: int64

# %%
#Observations from day one, two and three infered from the telcom datasets 
#the value column is the only one that is an integer the rest are strings-Might need to change the date and time column 
#The only column that contains missing values is the site_id column 
#The most used product on day one was Voice and on day two and three was SMS 
#The highest billing price paid for MTN products on the three days for the three products was as follows:
#day one
    #Voice    1860
    #data     4440
    #sms       100
#for day two
    #Voice    3380
    #data     1000
    #sms       100
#for day three
    #Voice    12900
    #data       832
    #sms        100

# %%
#since the three datasets contain the same number of rows and columns,it is easier to concatenate and clean then analyze the data
#concatenate data 
telcom_df=pd.concat([df1,df2,df3],axis=0)
telcom_df
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0     1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3     6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4     02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv
# ...               ...       ...       ...         ...         ...
# 4996  0ab2acd804d01fe     19e2e     19e2e  2aa04dcab7  f7d63a29e5
# 4997  4c8098eb6ea1a41     19e2e     19e2e  7f1f2f889f  b4ddb9e93c
# 4998  9d064f013e2cab2     19e2e     19e2e  a4731e780e  d68260ef50
# 4999  f9ff5af59cf0d68     19e2e     19e2e  98ed726da2  b4130b54ab
# 5000  7e60838216482a7     19e2e     19e2e  1c11a2fcbb  6d70dae094
#
# [15003 rows x 10 columns]

# %%
#Clean data by , dropping unnecessary columns, checking for duplicate values, checking for unique values and handling missing data
#drop unnecessary columns 
telcom_df.drop(['COUNTRY_A','COUNTRY_B','CELL_ON_SITE'],axis=1)
# Out:
#      PRODUCT  VALUE              DATE_TIME  DW_A_NUMBER_INT  DW_B_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0  49fae048b547780  1a49f8b0ded9de6
# 1        sms      0  2012-05-06 23:05:25.0  7a54a6eaee19e65  93343ba6e41af95
# 2        sms     25  2012-05-06 23:05:41.0  6008887b0207d82  7aacc9709ce0a20
# 3      Voice     56  2012-05-06 23:05:42.0  7370032e20f4e96  6af4a60e74c91d3
# 4      Voice     14  2012-05-06 23:06:29.0  966ba4656e38e62  02aa736ee555d5c
# ...      ...    ...                    ...              ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0  467333ade2b4b9c  0ab2acd804d01fe
# 4997   Voice     62  2012-05-09 00:01:43.0  e077a6b74c5053c  4c8098eb6ea1a41
# 4998   Voice     32  2012-05-09 00:01:43.0  77f53c39d27c050  9d064f013e2cab2
# 4999   Voice     30  2012-05-09 00:01:43.0  672ce74c418aa7a  f9ff5af59cf0d68
# 5000   Voice     60  2012-05-09 00:01:43.0  6edeb4c55714650  7e60838216482a7
#
#          CELL_ID     SITE_ID
# 0     /TJNe+Mmtu  /TJNe+Mmtu
# 1     /+cKZKIp41  /+cKZKIp41
# 2     /u0FSD+ahi  /u0FSD+ahi
# 3     +cNeJzsTp3  +cNeJzsTp3
# 4     051KhYDCpv  051KhYDCpv
# ...          ...         ...
# 4996  2aa04dcab7  f7d63a29e5
# 4997  7f1f2f889f  b4ddb9e93c
# 4998  a4731e780e  d68260ef50
# 4999  98ed726da2  b4130b54ab
# 5000  1c11a2fcbb  6d70dae094
#
# [15003 rows x 7 columns]

# %%
#check for duplicate values
telcom_df.duplicated().sum()
# Out:
# 253

# %%
telcom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14750 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          14750 non-null  object
#  1   VALUE            14750 non-null  int64
#  2   DATE_TIME        14750 non-null  object
#  3   CELL_ON_SITE     14750 non-null  object
#  4   DW_A_NUMBER_INT  14750 non-null  object
#  5   DW_B_NUMBER_INT  14750 non-null  object
#  6   COUNTRY_A        14750 non-null  object
#  7   COUNTRY_B        14750 non-null  object
#  8   CELL_ID          14750 non-null  object
#  9   SITE_ID          12789 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
#view the duplicated rows 
telcom_df.loc[telcom_df.duplicated(),:]
#drop duplicates 
telcom_df=telcom_df.drop_duplicates()

# %%
telcom_df.shape
# Out:
# (14750, 10)

# %%
#view number missing values in data 
telcom_df.isnull().sum()
# Out:
# PRODUCT               0
# VALUE                 0
# DATE_TIME             0
# CELL_ON_SITE          0
# DW_A_NUMBER_INT       0
# DW_B_NUMBER_INT       0
# COUNTRY_A             0
# COUNTRY_B             0
# CELL_ID               0
# SITE_ID            1997
# dtype: int64

# %%
#drop missing values only found in site_id column so drop via subset
telcom_df.dropna()
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0     1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3     6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4     02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv
# ...               ...       ...       ...         ...         ...
# 4996  0ab2acd804d01fe     19e2e     19e2e  2aa04dcab7  f7d63a29e5
# 4997  4c8098eb6ea1a41     19e2e     19e2e  7f1f2f889f  b4ddb9e93c
# 4998  9d064f013e2cab2     19e2e     19e2e  a4731e780e  d68260ef50
# 4999  f9ff5af59cf0d68     19e2e     19e2e  98ed726da2  b4130b54ab
# 5000  7e60838216482a7     19e2e     19e2e  1c11a2fcbb  6d70dae094
#
# [13006 rows x 10 columns]

# %%
#check for unique values
telcom_df.nunique()
# Out:
# PRODUCT                3
# VALUE                371
# DATE_TIME           2143
# CELL_ON_SITE          10
# DW_A_NUMBER_INT    10697
# DW_B_NUMBER_INT     8424
# COUNTRY_A              1
# COUNTRY_B              2
# CELL_ID             2677
# SITE_ID             1357
# dtype: int64

# %%
#change the datatype of the date and time 
telcom_df['DATE_TIME'] = pd.to_datetime(telcom_df['DATE_TIME'])
# Out:
# <ipython-input-49-ccdc7b2d08d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   telcom_df['DATE_TIME'] = pd.to_datetime(telcom_df['DATE_TIME'])

# %%
#check if the date and time dtype has changed 
telcom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15003 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          15003 non-null  object
#  1   VALUE            15003 non-null  int64
#  2   DATE_TIME        15003 non-null  datetime64[ns]
#  3   CELL_ON_SITE     15003 non-null  object
#  4   DW_A_NUMBER_INT  15003 non-null  object
#  5   DW_B_NUMBER_INT  15003 non-null  object
#  6   COUNTRY_A        15003 non-null  object
#  7   COUNTRY_B        15003 non-null  object
#  8   CELL_ID          15003 non-null  object
#  9   SITE_ID          13006 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
#Next step is to analyse the geo data set and merge them to answer the questions

# %%
#geo data set 
df_cells_geo=pd.read_csv('C:\\Users\\mac\Downloads\cells_geo - cells_geo.csv')
#split the dataset
df_cells_geo=df_cells_geo[';VILLES;STATUS;LOCALISATION;DECOUPZONE;ZONENAME;LONGITUDE;LATITUDE;REGION;AREA;CELL_ID;SITE_CODE'].str.split(pat=';',n=11, expand=True)
#drop the column 0
df_cells_geo.drop([0],axis=1,inplace=True)
#rename the columns 
df_cells_geo.columns=['VILLES','STATUS','LOCALISATION','DECOUPZONE','ZONENAME','LONGITUDE','LATITUDE','REGION','AREA','CELL_ID','SITE_CODE']
#replace empty whitespace with NaN
df_cells_geo.replace(r'^\s*$', np.nan, regex=True, inplace=True)
df_cells_geo
# Out:
#         VILLES      STATUS LOCALISATION       DECOUPZONE             ZONENAME  \
# 0       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 1       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 2       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 3      ASSINIE  In Service    INTERIEUR        Grand-EST          "ASSINIE"""
# 4      ASSINIE  In Service    INTERIEUR        Grand-EST          "ASSINIE"""
# ...        ...         ...          ...              ...                  ...
# 3969  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3970  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3971  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3972  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3973  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
#
#               LONGITUDE          LATITUDE     REGION          AREA  \
# 0     -4.00066666666667  5.36819444444444     LAGUNE           NaN
# 1     -4.00066666666667  5.36819444444444     LAGUNE           NaN
# 2     -4.00066666666667  5.36819444444444     LAGUNE           NaN
# 3     -3.48846666666667  5.15876111111111  SUD COMOE           NaN
# 4     -3.48846666666667  5.15876111111111  SUD COMOE           NaN
# ...                 ...               ...        ...           ...
# 3969  -6.03969444444444  7.42861111111111   MARAHOUE  CENTRE NORTH
# 3970  -6.03969444444444  7.42861111111111   MARAHOUE  CENTRE NORTH
# 3971           -6.06545  7.44459166666667   MARAHOUE  CENTRE NORTH
# 3972           -6.06545  7.44459166666667   MARAHOUE  CENTRE NORTH
# 3973           -6.06545  7.44459166666667   MARAHOUE  CENTRE NORTH
#
#          CELL_ID   SITE_CODE
# 0     fbb2e75af3  0bb492ef17
# 1     1502501d78  0bb492ef17
# 2     0c2e182a0c  0bb492ef17
# 3     69bdfc69fd  8a1e6ce31f
# 4     7a1029d2ab  8a1e6ce31f
# ...          ...         ...
# 3969  1cfc2d7ab1  f91ed8d2e9
# 3970  3ae1708153  f91ed8d2e9
# 3971  cb71f8a29c  61bee9c70c
# 3972  d4a6a0b645  61bee9c70c
# 3973  f9f3e42589  61bee9c70c
#
# [3974 rows x 11 columns]

# %%
#cleaning the geo data set
#missing values, duplicate values, drop unnecessary columns, outliers 
#handle our missing values 
df_cells_geo.isnull().sum()
#drop missing values 
df_cells_geo.dropna()
# Out:
#         VILLES      STATUS LOCALISATION    DECOUPZONE               ZONENAME  \
# 23       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 24       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 25       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 26       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 27       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# ...        ...         ...          ...           ...                    ...
# 3969  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3970  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3971  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3972  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3973  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
#
#               LONGITUDE          LATITUDE    REGION           AREA  \
# 23    -4.01413888888889            5.4335    LAGUNE  ABIDJAN NORTH
# 24    -4.01413888888889            5.4335    LAGUNE  ABIDJAN NORTH
# 25    -4.01413888888889            5.4335    LAGUNE  ABIDJAN NORTH
# 26    -4.01413888888889            5.4335    LAGUNE  ABIDJAN NORTH
# 27    -4.01413888888889            5.4335    LAGUNE  ABIDJAN NORTH
# ...                 ...               ...       ...            ...
# 3969  -6.03969444444444  7.42861111111111  MARAHOUE   CENTRE NORTH
# 3970  -6.03969444444444  7.42861111111111  MARAHOUE   CENTRE NORTH
# 3971           -6.06545  7.44459166666667  MARAHOUE   CENTRE NORTH
# 3972           -6.06545  7.44459166666667  MARAHOUE   CENTRE NORTH
# 3973           -6.06545  7.44459166666667  MARAHOUE   CENTRE NORTH
#
#          CELL_ID   SITE_CODE
# 23    f740406877  0f34c36ac5
# 24    959e54c8f7  0f34c36ac5
# 25    56b7e7000c  0f34c36ac5
# 26    bc51c17a6f  0f34c36ac5
# 27    e460975c9f  0f34c36ac5
# ...          ...         ...
# 3969  1cfc2d7ab1  f91ed8d2e9
# 3970  3ae1708153  f91ed8d2e9
# 3971  cb71f8a29c  61bee9c70c
# 3972  d4a6a0b645  61bee9c70c
# 3973  f9f3e42589  61bee9c70c
#
# [3880 rows x 11 columns]

# %%
#duplicate values 
df_cells_geo.duplicated().sum()
# Out:
# 43

# %%
#viewing the duplicate values 
df_cells_geo.loc[df_cells_geo.duplicated(), :]
#dropping our duplicate values 
df_cells_geo.drop_duplicates()
# Out:
#         VILLES      STATUS LOCALISATION       DECOUPZONE             ZONENAME  \
# 0       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 1       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 2       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 3      ASSINIE  In Service    INTERIEUR        Grand-EST          "ASSINIE"""
# 4      ASSINIE  In Service    INTERIEUR        Grand-EST          "ASSINIE"""
# ...        ...         ...          ...              ...                  ...
# 3969  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3970  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3971  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3972  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3973  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
#
#               LONGITUDE          LATITUDE     REGION          AREA  \
# 0     -4.00066666666667  5.36819444444444     LAGUNE           NaN
# 1     -4.00066666666667  5.36819444444444     LAGUNE           NaN
# 2     -4.00066666666667  5.36819444444444     LAGUNE           NaN
# 3     -3.48846666666667  5.15876111111111  SUD COMOE           NaN
# 4     -3.48846666666667  5.15876111111111  SUD COMOE           NaN
# ...                 ...               ...        ...           ...
# 3969  -6.03969444444444  7.42861111111111   MARAHOUE  CENTRE NORTH
# 3970  -6.03969444444444  7.42861111111111   MARAHOUE  CENTRE NORTH
# 3971           -6.06545  7.44459166666667   MARAHOUE  CENTRE NORTH
# 3972           -6.06545  7.44459166666667   MARAHOUE  CENTRE NORTH
# 3973           -6.06545  7.44459166666667   MARAHOUE  CENTRE NORTH
#
#          CELL_ID   SITE_CODE
# 0     fbb2e75af3  0bb492ef17
# 1     1502501d78  0bb492ef17
# 2     0c2e182a0c  0bb492ef17
# 3     69bdfc69fd  8a1e6ce31f
# 4     7a1029d2ab  8a1e6ce31f
# ...          ...         ...
# 3969  1cfc2d7ab1  f91ed8d2e9
# 3970  3ae1708153  f91ed8d2e9
# 3971  cb71f8a29c  61bee9c70c
# 3972  d4a6a0b645  61bee9c70c
# 3973  f9f3e42589  61bee9c70c
#
# [3931 rows x 11 columns]

# %%
#viewing the descriptive statistics of the df_cells_geo
df_cells_geo.describe()
# Out:
#         VILLES      STATUS LOCALISATION   DECOUPZONE              ZONENAME  \
# count     3974        3907         3974         3974                  3968
# unique     504           1            2           15                    33
# top     COCODY  In Service    INTERIEUR  Grand-OUEST  ZONE D - Grand-OUEST
# freq       354        3907         2305          528                   527
#
#                 LONGITUDE          LATITUDE  REGION           AREA  \
# count                3974              3974    3974           3951
# unique               1013              1025      19              6
# top     -4.02333333333333  5.29861111111111  LAGUNE  ABIDJAN NORTH
# freq                   12                12    1850           1222
#
#            CELL_ID   SITE_CODE
# count         3974        3974
# unique        3916        1029
# top     6750e0fb7b  20387d4292
# freq            39          42

# %%
df_cells_geo. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3974 entries, 0 to 3973
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   VILLES        3974 non-null   object
#  1   STATUS        3907 non-null   object
#  2   LOCALISATION  3974 non-null   object
#  3   DECOUPZONE    3974 non-null   object
#  4   ZONENAME      3968 non-null   object
#  5   LONGITUDE     3974 non-null   object
#  6   LATITUDE      3974 non-null   object
#  7   REGION        3974 non-null   object
#  8   AREA          3951 non-null   object
#  9   CELL_ID       3974 non-null   object
#  10  SITE_CODE     3974 non-null   object
# dtypes: object(11)
# memory usage: 341.6+ KB

# %%
#check for common values in the two dataframes to understand where to merge
 

telcom_df['SITE_ID'].isin(df_cells_geo['SITE_CODE']).value_counts()
# Out:
# True     10239
# False     4511
# Name: SITE_ID, dtype: int64

# %%
#A graph of the MTN product usage
telcom_df.PRODUCT.hist()
# Out:
# <AxesSubplot:>

# %%
#merge the geo dataset and telcom dataset 

df_merged=telcom_df.merge(df_cells_geo, left_on='SITE_ID', right_on='SITE_CODE')
df_merged
# Out:
#       PRODUCT  VALUE           DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0         sms      0 2012-05-07 00:00:00            1  8118c3aa53d6c7b
# 1         sms      0 2012-05-07 00:00:00            1  8118c3aa53d6c7b
# 2         sms      0 2012-05-07 00:00:00            1  8118c3aa53d6c7b
# 3         sms      0 2012-05-07 00:00:00            1  8118c3aa53d6c7b
# 4         sms      0 2012-05-07 00:00:00            1  8118c3aa53d6c7b
# ...       ...    ...                 ...          ...              ...
# 50313   Voice     17 2012-05-09 00:01:42            4  22e493a92442b73
# 50314   Voice     17 2012-05-09 00:01:42            4  22e493a92442b73
# 50315     sms      0 2012-05-09 00:01:43            2  32e2e7c90a9b0e9
# 50316     sms      0 2012-05-09 00:01:43            2  32e2e7c90a9b0e9
# 50317     sms      0 2012-05-09 00:01:43            2  32e2e7c90a9b0e9
#
#        DW_B_NUMBER_INT COUNTRY_A COUNTRY_B   CELL_ID_x     SITE_ID  ...  \
# 0      1d103ea638ad1f0     19e2e     19e2e  5d9dc897f7  1b5540c02d  ...
# 1      1d103ea638ad1f0     19e2e     19e2e  5d9dc897f7  1b5540c02d  ...
# 2      1d103ea638ad1f0     19e2e     19e2e  5d9dc897f7  1b5540c02d  ...
# 3      1d103ea638ad1f0     19e2e     19e2e  5d9dc897f7  1b5540c02d  ...
# 4      1d103ea638ad1f0     19e2e     19e2e  5d9dc897f7  1b5540c02d  ...
# ...                ...       ...       ...         ...         ...  ...
# 50313  c9e2c9c2fa3795a     19e2e     19e2e  2f50f4a1fb  cc45940406  ...
# 50314  c9e2c9c2fa3795a     19e2e     19e2e  2f50f4a1fb  cc45940406  ...
# 50315  32e2e7c90a9b0e9     19e2e     19e2e  25c671778e  ab91f5b21d  ...
# 50316  32e2e7c90a9b0e9     19e2e     19e2e  25c671778e  ab91f5b21d  ...
# 50317  32e2e7c90a9b0e9     19e2e     19e2e  25c671778e  ab91f5b21d  ...
#
#            STATUS LOCALISATION      DECOUPZONE                 ZONENAME  \
# 0      In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# 1      In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# 2      In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# 3      In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# 4      In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# ...           ...          ...             ...                      ...
# 50313  In Service      ABIDJAN  Abidjan_CENTRE  ZONE B - Abidjan_CENTRE
# 50314  In Service      ABIDJAN  Abidjan_CENTRE  ZONE B - Abidjan_CENTRE
# 50315  In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# 50316  In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
# 50317  In Service    INTERIEUR      Grand-NORD      ZONE A - Grand-NORD
#
#                LONGITUDE          LATITUDE             REGION           AREA  \
# 0      -5.02713888888889  7.71841666666667  VALLEE DU BANDAMA   CENTRE NORTH
# 1      -5.02713888888889  7.71841666666667  VALLEE DU BANDAMA   CENTRE NORTH
# 2      -5.02713888888889  7.71841666666667  VALLEE DU BANDAMA   CENTRE NORTH
# 3      -5.02713888888889  7.71841666666667  VALLEE DU BANDAMA   CENTRE NORTH
# 4      -5.02713888888889  7.71841666666667  VALLEE DU BANDAMA   CENTRE NORTH
# ...                  ...               ...                ...            ...
# 50313  -4.02324722222222  5.34944166666667             LAGUNE  ABIDJAN NORTH
# 50314  -4.02324722222222  5.34944166666667             LAGUNE  ABIDJAN NORTH
# 50315  -5.17177777777778  7.77705555555556  VALLEE DU BANDAMA   CENTRE NORTH
# 50316  -5.17177777777778  7.77705555555556  VALLEE DU BANDAMA   CENTRE NORTH
# 50317  -5.17177777777778  7.77705555555556  VALLEE DU BANDAMA   CENTRE NORTH
#
#         CELL_ID_y   SITE_CODE
# 0      24ccdda3d5  1b5540c02d
# 1      ebfc58af70  1b5540c02d
# 2      ba8ce6e4ef  1b5540c02d
# 3      c2545171dc  1b5540c02d
# 4      f15bd5483f  1b5540c02d
# ...           ...         ...
# 50313  c179f33d5e  cc45940406
# 50314  0a3f751619  cc45940406
# 50315  0427a26d34  ab91f5b21d
# 50316  7c72293cf2  ab91f5b21d
# 50317  be18b5b981  ab91f5b21d
#
# [50318 rows x 21 columns]

# %%
#Data Analysis 
#maximum spent on MTN Products
df_merged.groupby('PRODUCT')['VALUE'].sum()
# Out:
# PRODUCT
# Voice    1175747
# sms       232100
# Name: VALUE, dtype: int64

# %%
#most used city for the three days 
df_merged['VILLES'].value_counts().idxmax()
# Out:
# 'YOPOUGON'

# %%
#most used product for the three days 
df_merged['PRODUCT'].value_counts().idxmax()
# Out:
# 'sms'

# %%
#which cities were the most used during business and home hours 
#working hours in ivory coast are 8AM to 5PM that means home hours are 6PM-7AM
#Source for working hours was google site https://www.expatfinder.com/ivory-coast/expat-guides/article/working-in-ivory-coast/1915

# %%
#dates given in dataset 6th-9th May 2012 
#create ts to check the most used product during business hours 8-5

# %%
#Analysis 
##Observations from day one, two and three infered from the telcom datasets 
#the value column is the only one that is an integer the rest are strings-Might need to change the date and time column 
#The only column that contains missing values is the site_id column 
#The most used product on day one was Voice and on day two and three was SMS 
#The highest billing price paid for MTN products on the three days for the three products was as follows:
#day one
    #Voice    1860
    #data     4440
    #sms       100
#for day two
    #Voice    3380
    #data     1000
    #sms       100
#for day three
    #Voice    12900
    #data       832
    #sms        100
#upon further cleaning and analysis of the data, we inferred that the city with the highest usage was Yopougon and 
#The most used product was sms in the three days but the product that had the highest value was Voice

#Business and home hours 

#Recommendations
#From the analysis as Yopougon was the city with the highest usage, MTN should consider expanding their infrastructure there specifically on the voice and sms products
#To maximize their profitability MTN should upgrade their infrastructure on Voice 
#To increase customer base, MTN should focus their marketing strategy on data products 
#To ensure sustainability  on the usage of sms products, MTN should continue current marketing efforts on the product.
#Based on home and business hours
